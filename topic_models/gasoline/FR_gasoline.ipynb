# %% [markdown]
# # France topic analysis - Gasoline

# %% [markdown]
# #### 0. Dependencies and Setup

# %%
import sys
sys.path.insert(0, '../..')
import lib as l

# %%
df = l.U.load_df("France", keyword="gasoline", is_parent=False)
# Out:
# Loaded data from France, took 12.88 seconds
# Dataset has size (36683, 3) and columns ['date' 'article' 'lemmas']

# %%
l.PL.plot_articles_over_time(df, "gasoline")

# %%
l.PL.plot_occurences(df, "gasoline", l.C.GASOLINE["fr"])

# %% [markdown]
# ## Analyze topic modelling

# %% [markdown]
# ### First time period : 1820-1850

# %%
timespan_1 = l.PR.Timespan(df, "gasoline", "fr", 0)
# Out:
# Timespan from 1826 to 1840 has 266 articles.
# Successfully loaded model.
# TOPIC 0
# ['republique', 'politique', 'gouvernement', 'presse', 'president', 'republicain', 'liberte', 'citoyen', 'milieu', 'reine', 'laisse', 'vrai', 'mort', 'affaire', 'electeur']
# TOPIC 1
# ['savoir', 'blanc', 'trop', 'cher', 'redacteur', 'chose', 'moment', 'tour', 'rendre', 'tenir', 'être', 'main', 'sortir', 'droit', 'feuille']
# TOPIC 2
# ['representation', 'ville', 'recevoir', 'cheval', 'pere', 'part', 'travail', 'payer', 'porte', 'famille', 'action', 'matin', 'trouver', 'annoncer', 'valoir']
# TOPIC 3
# ['theâtre', 'mlle', 'ouvrage', 'acteur', 'paraître', 'auteur', 'musique', 'livraison', 'piece', 'joue', 'public', 'royal', 'jouer', 'soir', 'directeur']
# TOPIC 4
# ['avoue', 'etoffe', 'meuble', 'louer', 'Montmartre', 'flacon', 'adjudication', 'notaire', 'Neuve', 'tribunal', 'civil', 'maison', 'tache', 'midi', 'renseignemen']
# TOPIC 5
# ...

# %%
timespan_1.assign_topics(["politics", "newspaper", "public interest", "theatre", "real estate", "family", "politics", "literature", "medicine", "literature", "theatre"])
l.PL.plot_num_of_articles_per_topic(timespan_1)
timespan_1.save()
# Out:
# Keyword petrole not in vocabulary used to train model.
# Keyword essence most likely belongs to topics :
#   - REAL ESTATE : topic(s) 4
#   - NEWSPAPER : topic(s) 1

# %% [markdown]
# ### Second time period : 1850-1870

# %%
timespan_2 = l.PR.Timespan(df, "gasoline", "fr", 1)
# Out:
# Timespan from 1854 to 1869 has 992 articles.
# Successfully loaded model.
# TOPIC 0
# ['flacon', 'traitement', 'maladie', 'dartres', 'bouton', 'Lombards', 'excellence', 'poudre', 'humeur', 'medecin', 'chocolat', 'virus', 'Barbe', 'depuratif', 'guerison']
# TOPIC 1
# ['bien', 'homme', 'faire', 'vouloir', 'monsieur', 'avoir', 'savoir', 'voir', 'falloir', 'dire', 'petit', 'Monsieur', 'femme', 'croire', 'prendre']
# TOPIC 2
# ['paix', 'coin', 'blanc', 'italien', 'face', 'boulevard', 'tribunal', 'mode', 'frere', 'luxe', 'Richelieu', 'chevalier', 'ville', 'george', 'Dupin']
# TOPIC 3
# ['franc', 'maison', 'gouvernement', 'gros', 'billet', 'general', 'Societe', 'nouveau', 'prix', 'loterie', 'Colbert', 'directeur', 'Compagnie', 'action', 'million']
# TOPIC 4
# ['journal', 'être', 'garde', 'côte', 'coup', 'part', 'droit', 'tete', 'mari', 'pied', 'faire', 'presse', 'president', 'chambre', 'Dieu']

# %%
timespan_2.assign_topics(["medicine", "family", "public interest", "companies", "newspaper"])
l.PL.plot_num_of_articles_per_topic(timespan_2)
timespan_2.save()
# Out:
# Keyword petrole most likely belongs to topics :
#   - COMPANIES : topic(s) 3
#   - PUBLIC INTEREST : topic(s) 2
# Keyword essence most likely belongs to topics :
#   - MEDICINE : topic(s) 0
#   - PUBLIC INTEREST : topic(s) 2
#   - FAMILY : topic(s) 1

# %% [markdown]
# ### Third time period : 1870-1880

# %%
timespan_3 = l.PR.Timespan(df, "gasoline", "fr", 2)
# Out:
# Timespan from 1870 to 1879 has 1875 articles.
# Successfully loaded model.
# TOPIC 0
# ['voyageur', 'reine', 'russe', 'Russie', 'course', 'cheval', 'prince', 'marquis', 'anglais', 'fete', 'degre', 'Rome', 'medaille', 'dimanche', 'chien']
# TOPIC 1
# ['Restaurant', 'boulangerie', 'café', 'comestible', 'Boucherie', 'Hôtel', 'Truffes', 'Cafe', 'Pâtes', 'glacier', 'expedition', 'Montmartre', 'honore', 'chocolat', 'bontoux']
# TOPIC 2
# ['franc', 'action', 'mlle', 'cours', 'banque', 'obligation', 'juillet', 'centime', 'Societe', 'bourse', 'valeur', 'Compagnie', 'titre', 'prix', 'million']
# TOPIC 3
# ['bataillon', 'prussien', 'capitaine', 'garde', 'sergent', 'major', 'colonel', 'commandant', 'lieutenant', 'regimer', 'soldat', 'federe', 'service', 'national', 'campagne']
# TOPIC 4
# ['Thiers', 'gauche', 'Gambetta', 'depute', 'gouvernement', 'droite', 'majorite', 'vote', 'election', 'republique', 'republicain', 'ministre', 'conservateur', 'commission', 'seance']
# TOPIC 5
# ...

# %%
timespan_3.assign_topics(["travel", "stores", "stick", "war", "politics", "war", "body", "literature", "theatre", "military", "crime", "crime", "real estate", "perfume"])
l.PL.plot_num_of_articles_per_topic(timespan_3)
timespan_3.save()
# Out:
# Keyword petrole most likely belongs to topics :
#   - CRIME : topic(s) 10, 11
#   - WAR : topic(s) 3, 5
#   - TRAVEL : topic(s) 0
# Keyword essence most likely belongs to topics :
#   - PERFUME : topic(s) 13
#   - REAL ESTATE : topic(s) 12
#   - STORES : topic(s) 1
#   - LITERATURE : topic(s) 7
#   - CRIME : topic(s) 10, 11

# %% [markdown]
# ### Fourth time period : 1880-1890

# %%
timespan_4 = l.PR.Timespan(df, "gasoline", "fr", 3)
# Out:
# Timespan from 1880 to 1889 has 1166 articles.
# Successfully loaded model.
# TOPIC 0
# ['theâtre', 'mlle', 'rôle', 'acte', 'representation', 'artiste', 'scene', 'comedie', 'succe', 'musique', 'drame', 'piece', 'accessit', 'soir', 'concert']
# TOPIC 1
# ['ninon', 'toilette', 'exotique', 'cheveux', 'parf', 'peau', 'lait', 'blanc', 'bain', 'franco', 'fleur', 'flacon', 'lampe', 'soie', 'cafe']
# TOPIC 2
# ['banque', 'Credit', 'incendie', 'action', 'credit', 'comptant', 'terme', 'valeur', 'centime', 'obligation', 'cote', 'caisse', 'capsule', 'Toilette', 'coupon']
# TOPIC 3
# ['Gambetta', 'politique', 'gouvernement', 'guerre', 'pouvoir', 'pays', 'question', 'parti', 'ministre', 'republique', 'falloir', 'ministere', 'faire', 'vouloir', 'droit']
# TOPIC 4
# ['franc', 'somme', 'produire', 'compte', 'beaucoup', 'voie', 'titre', 'million', 'travail', 'decembre', 'condition', 'annee', 'traite', 'affaire', 'courant']
# TOPIC 5
# ...

# %%
timespan_4.assign_topics(["theatre", "perfume", "stock", "politics", "production", "crime", "politics", "random", "aristocracy", "religion", "family", "real estate"])
l.PL.plot_num_of_articles_per_topic(timespan_4)
timespan_4.save()
# Out:
# Keyword petrole most likely belongs to topics :
#   - PERFUME : topic(s) 1
#   - CRIME : topic(s) 5
#   - STOCK : topic(s) 2
# Keyword essence most likely belongs to topics :
#   - STOCK : topic(s) 2
#   - REAL ESTATE : topic(s) 11
#   - PERFUME : topic(s) 1
#   - RELIGION : topic(s) 9
#   - THEATRE : topic(s) 0

# %% [markdown]
# ### Fifth time period : 1890-1900

# %%
timespan_5 = l.PR.Timespan(df, "gasoline", "fr", 4)
# Out:
# Timespan from 1890 to 1899 has 2551 articles.
# Successfully loaded model.
# TOPIC 0
# ['noir', 'blanc', 'jolie', 'genre', 'couleur', 'toilette', 'fleur', 'grand', 'costume', 'vert', 'rouge', 'goût', 'rose', 'bleu', 'table']
# TOPIC 1
# ['comte', 'mlle', 'prince', 'comtesse', 'marquis', 'general', 'fete', 'baron', 'lieutenant', 'princesse', 'professeur', 'ancien', 'Henri', 'directeur', 'Leon']
# TOPIC 2
# ['guerre', 'politique', 'pays', 'gouvernement', 'falloir', 'ministre', 'question', 'faire', 'pouvoir', 'France', 'bien', 'droit', 'point', 'français', 'parti']
# TOPIC 3
# ['longueur', 'course', 'mutuel', 'prix', 'Pari', 'battre', 'club', 'troisieme', 'metre', 'automobile', 'place', 'kilometre', 'coureur', 'yacht', 'match']
# TOPIC 4
# ['scene', 'chose', 'acte', 'rôle', 'œuvre', 'theâtre', 'artiste', 'bien', 'jamais', 'cœur', 'piece', 'monsieur', 'tableau', 'oeil', 'trop']
# TOPIC 5
# ...

# %%
timespan_5.assign_topics(["fashion", "aristocracy", "politics", "car race", "theatre", "companies", "crime", "theatre"])
l.PL.plot_num_of_articles_per_topic(timespan_5)
timespan_5.save()
# Out:
# Keyword petrole most likely belongs to topics :
#   - THEATRE : topic(s) 4, 7
#   - CAR RACE : topic(s) 3
#   - COMPANIES : topic(s) 5
#   - FASHION : topic(s) 0
#   - CRIME : topic(s) 6
# Keyword essence most likely belongs to topics :
#   - THEATRE : topic(s) 4, 7
#   - FASHION : topic(s) 0
#   - POLITICS : topic(s) 2

# %% [markdown]
# ### Sixth time period : 1900-1910

# %%
timespan_6 = l.PR.Timespan(df, "gasoline", "fr", 5)
# Out:
# Timespan from 1900 to 1909 has 3172 articles.
# Successfully loaded model.
# TOPIC 0
# ['comte', 'prix', 'mlle', 'longueur', 'voiture', 'course', 'mutuel', 'marquis', 'Pari', 'baron', 'comtesse', 'gagner', 'comtess', 'vicomte', 'club']
# TOPIC 1
# ['ministre', 'être', 'president', 'general', 'conseil', 'gouvernement', 'vouloir', 'politique', 'falloir', 'homme', 'chose', 'bien', 'voir', 'hier', 'droit']
# TOPIC 2
# ['cuisiniere', 'refer', 'valet', 'reference', 'million', 'place', 'menage', 'demande', 'Figaro', 'desir', 'chambre', 'ecrire', 'banque', 'franc', 'Compagnie']

# %%
timespan_6.assign_topics(["race", "politics", "hiring"])
l.PL.plot_num_of_articles_per_topic(timespan_6)
timespan_6.save()
# Out:
# Keyword petrole most likely belongs to topics :
#   - HIRING : topic(s) 2
#   - RACE : topic(s) 0
# Keyword essence most likely belongs to topics :
#   - RACE : topic(s) 0
#   - HIRING : topic(s) 2
#   - POLITICS : topic(s) 1

# %% [markdown]
# ### Seventh time period : 1910-1920

# %%
timespan_7 = l.PR.Timespan(df, "gasoline", "fr", 6)
# Out:
# Timespan from 1910 to 1919 has 3425 articles.
# Successfully loaded model.
# TOPIC 0
# ['comte', 'comtesse', 'marquis', 'comtess', 'mlle', 'baron', 'prince', 'ministre', 'noir', 'baronne', 'chapeau', 'docteur', 'vicomte', 'fils', 'mort']
# TOPIC 1
# ['bien', 'femme', 'petit', 'jeune', 'voir', 'homme', 'chose', 'être', 'savoir', 'vouloir', 'rien', 'temps', 'trop', 'grand', 'beau']
# TOPIC 2
# ['mlle', 'prix', 'theâtre', 'mutuel', 'Pari', 'representation', 'matinee', 'longueur', 'voiture', 'place', 'club', 'comedie', 'metre', 'automobile', 'gagner']
# TOPIC 3
# ['franc', 'valeur', 'allemand', 'guerre', 'gouvernement', 'marche', 'ferme', 'paix', 'contre', 'politique', 'cours', 'calme', 'russe', 'conseil', 'affaire']
# TOPIC 4
# ['Deep', 'Gold', 'pref', 'Copper', 'Consolidated', 'Mines', 'Investment', 'Reef', 'Main', 'Rand', 'Roodepoort', 'prov', 'Oriental', 'Goldfields', 'General']

# %%
timespan_7.assign_topics(["aristocracy", "random", "cars", "politics", "international economy"])
l.PL.plot_num_of_articles_per_topic(timespan_7)
timespan_7.save()
# Out:
# Keyword petrole most likely belongs to topics :
#   - POLITICS : topic(s) 3
#   - CARS : topic(s) 2
# Keyword essence most likely belongs to topics :
#   - CARS : topic(s) 2
#   - ARISTOCRACY : topic(s) 0

# %% [markdown]
# ### Eigth time period : 1920-1930

# %%
timespan_8 = l.PR.Timespan(df, "gasoline", "fr", 7)
# Out:
# Timespan from 1920 to 1929 has 9928 articles.
# Successfully loaded model.
# TOPIC 0
# ['mlle', 'Theâtre', 'matinee', 'concert', 'revue', 'comedie', 'salle', 'spectacle', 'soir', 'acte', 'theâtre', 'soiree', 'musique', 'Concert', 'representation']
# TOPIC 1
# ['Mines', 'Copper', 'American', 'Steel', 'Rand', 'joui', 'Houilleres', 'fonc', 'Chine', 'Dutch', 'pacific', 'Ohio', 'nouv', 'Shell', 'Loire']
# TOPIC 2
# ['comte', 'comtesse', 'marquis', 'mlle', 'mort', 'hier', 'comtess', 'baron', 'vicomte', 'princesse', 'legion', 'baronne', 'prince', 'fille', 'fils']
# TOPIC 3
# ['championnat', 'mutuel', 'prix', 'franc', 'longueur', 'match', 'metre', 'course', 'Pari', 'club', 'mlle', 'Gagnant', 'place', 'coupe', 'finale']
# TOPIC 4
# ['faire', 'falloir', 'bien', 'pouvoir', 'vouloir', 'savoir', 'public', 'être', 'rien', 'voir', 'guerre', 'raison', 'radical', 'donner', 'point']
# TOPIC 5
# ...

# %%
timespan_8.assign_topics(["theatre", "international economy", "aristocracy", "race", "war", "production", "stock", "stock", "politics", "body", "airplanes", "fashion"])
l.PL.plot_num_of_articles_per_topic(timespan_8)
timespan_8.save()
# Out:
# Keyword petrole most likely belongs to topics :
#   - PRODUCTION : topic(s) 5
#   - STOCK : topic(s) 6, 7
#   - INTERNATIONAL ECONOMY : topic(s) 1
#   - POLITICS : topic(s) 8
#   - FASHION : topic(s) 11
#   - ARISTOCRACY : topic(s) 2
# Keyword essence most likely belongs to topics :
#   - FASHION : topic(s) 11
#   - PRODUCTION : topic(s) 5
#   - AIRPLANES : topic(s) 10
#   - STOCK : topic(s) 6, 7
#   - WAR : topic(s) 4

# %% [markdown]
# ### Ninth time period : 1930 onwards

# %%
timespan_9 = l.PR.Timespan(df, "gasoline", "fr", 8)
# Out:
# Timespan from 1930 to 1942 has 13308 articles.
# Successfully loaded model.
# TOPIC 0
# ['petit', 'bien', 'mort', 'femme', 'jeune', 'voir', 'homme', 'faire', 'beau', 'noir', 'être', 'vieux', 'savoir', 'vouloir', 'chose']
# TOPIC 1
# ['guerre', 'allemand', 'ministre', 'gouvernement', 'politique', 'commission', 'president', 'conseil', 'question', 'contre', 'pays', 'pouvoir', 'faire', 'être', 'peuple']
# TOPIC 2
# ['amortissable', 'Nord', 'Credit', 'preced', 'electricite', 'Lyon', 'Bons', 'energie', 'suer', 'parisien', 'foncier', 'Cinema', 'Generale', 'Santa', 'Tresor']
# TOPIC 3
# ['franc', 'valeur', 'contre', 'hausse', 'inch', 'baisse', 'marche', 'banque', 'ferme', 'capital', 'action', 'million', 'semaine', 'dividende', 'titre']
# TOPIC 4
# ['Maroc', 'American', 'fonc', 'Rand', 'Mines', 'part', 'Copper', 'Chine', 'energie', 'textile', 'priv', 'Loire', 'Distillerie', 'rhône', 'tunisien']
# TOPIC 5
# ...

# %%
timespan_9.assign_topics(["family", "war", "stock", "stock", "international economy", "theatre", "aristocracy"])
l.PL.plot_num_of_articles_per_topic(timespan_9)
timespan_9.save()
# Out:
# Keyword petrole most likely belongs to topics :
#   - STOCK : topic(s) 2, 3
#   - WAR : topic(s) 1
#   - INTERNATIONAL ECONOMY : topic(s) 4
#   - ARISTOCRACY : topic(s) 6
# Keyword essence most likely belongs to topics :
#   - FAMILY : topic(s) 0
#   - ARISTOCRACY : topic(s) 6
#   - WAR : topic(s) 1

# %% [markdown]
# ## Overall top 10 topics

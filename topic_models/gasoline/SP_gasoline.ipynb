# %% [markdown]
# # Spain topic analysis - Gasoline

# %% [markdown]
# #### 0. Dependencies and Setup

# %%
import sys
sys.path.insert(0, '../..')
import lib as l

# %%
df = l.U.load_df("Spain", keyword="gasoline", is_parent=False)
# Out:
# Loaded data from Spain, took 2.703 seconds
# Dataset has size (9319, 3) and columns ['date' 'article' 'lemmas']

# %%
l.PL.plot_articles_over_time(df, "gasoline")

# %%
l.PL.plot_occurences(df, "gasoline", l.C.GASOLINE["sp"])

# %% [markdown]
# ## Analyze topic modelling

# %% [markdown]
# ### First time period : 1860-1880

# %%
timespan_1 = l.PR.Timespan(df, "gasoline", "sp", 0)
# Out:
# Timespan from 1867 to 1879 has 667 articles.
# Successfully loaded model.
# TOPIC 0
# ['hombre', 'vida', 'querer', 'España', 'sistema', 'pobre', 'necesitar', 'tanto', 'historia', 'necesario', 'cosa', 'buscar', 'espiritu', 'merecer', 'vivir']
# TOPIC 1
# ['carlista', 'herido', 'voluntario', 'federal', 'Republica', 'partida', 'soldado', 'faccion', 'general', 'tropa', 'fuerza', 'arma', 'columna', 'batallon', 'prisionero']
# TOPIC 2
# ['idem', 'precio', 'sermon', 'surtido', 'frasco', 'lampara', 'lata', 'cuarto', 'Señora', 'vender', 'cocina', 'noveno', 'tubo', 'principal', 'baño']
# TOPIC 3
# ['millón', 'vino', 'derecho', 'impuesto', 'pesetas', 'producto', 'tarifa', 'consumo', 'recargo', 'baja', 'articulo', 'aceite', 'comercio', 'kilogramo', 'aumento']
# TOPIC 4
# ['ayer', 'gobernador', 'Jose', 'distrito', 'nombrar', 'provincia', 'Madrid', 'teniente', 'Sevilla', 'provincial', 'Antonio', 'Cadiz', 'general', 'Francisco', 'ministerio']
# TOPIC 5
# ...

# %%
timespan_1.assign_topics(["random", "war", "real estate", "commerce", "government", "theatre", "politics", "newspaper", "medicine", "bank", "random", "trains"])
l.PL.plot_num_of_articles_per_topic(timespan_1)
timespan_1.save()
# Out:
# Keyword gasolina not in vocabulary used to train model.
# Keyword bencina most likely belongs to topics :
#   - COMMERCE : topic(s) 3
# Keyword petroleo most likely belongs to topics :
#   - REAL ESTATE : topic(s) 2
#   - COMMERCE : topic(s) 3
#   - WAR : topic(s) 1
#   - TRAINS : topic(s) 11
#   - POLITICS : topic(s) 6
#   - MEDICINE : topic(s) 8

# %% [markdown]
# ### Second time period : 1880-1890

# %%
timespan_2 = l.PR.Timespan(df, "gasoline", "sp", 1)
# Out:
# Timespan from 1880 to 1889 has 928 articles.
# Successfully loaded model.
# TOPIC 0
# ['periodico', 'español', 'Paris', 'libertad', 'nombre', 'Carlos', 'liar', 'Alonso', 'inglés', 'Londres', 'centro', 'efecto', 'escuela', 'politico', 'premio']
# TOPIC 1
# ['llamar', 'deber', 'punto', 'falta', 'estudio', 'tanto', 'derecho', 'Francia', 'impuesto', 'Alemania', 'gasto', 'Inglaterra', 'situacion', 'industrial', 'recurso']
# TOPIC 2
# ['vida', 'hombre', 'libro', 'mano', 'mundo', 'vivir', 'querer', 'tierra', 'escrito', 'obra', 'papel', 'pasar', 'saber', 'paso', 'perder']
# TOPIC 3
# ['vender', 'precio', 'pral', 'botica', 'surtido', 'pesetas', 'domicilio', 'farmacia', 'casa', 'especialidad', 'olor', 'gratis', 'Plaza', 'venta', 'clase']
# TOPIC 4
# ['casa', 'noche', 'calle', 'joven', 'guardia', 'llamado', 'autoridad', 'numero', 'persona', 'incendio', 'fuego', 'mujer', 'tren', 'ciudad', 'detener']
# TOPIC 5
# ...

# %%
timespan_2.assign_topics(["public interest", "industry", "writing", "sakes", "crime", "war", "production", "random", "government", "crime", "import / export", "politics", "bullfight", "random"])
l.PL.plot_num_of_articles_per_topic(timespan_2)
timespan_2.save()
# Out:
# Keyword gasolina most likely belongs to topics :
#   - INDUSTRY : topic(s) 1
# Keyword bencina not in vocabulary used to train model.
# Keyword petroleo most likely belongs to topics :
#   - SAKES : topic(s) 3
#   - IMPORT / EXPORT : topic(s) 10
#   - CRIME : topic(s) 4, 9
#   - INDUSTRY : topic(s) 1
#   - POLITICS : topic(s) 11

# %% [markdown]
# ### Third time period : 1890-1900

# %%
timespan_3 = l.PR.Timespan(df, "gasoline", "sp", 2)
# Out:
# Timespan from 1890 to 1899 has 1256 articles.
# Successfully loaded model.
# TOPIC 0
# ['reales', 'litro', 'motor', 'maquina', 'arroba', 'electrico', 'kilo', 'aceite', 'aplicación', 'alumbrado', 'caldera', 'pesetas', 'idem', 'vagoneta', 'portatil']
# TOPIC 1
# ['civil', 'calle', 'noche', 'gobernador', 'obrero', 'orden', 'autoridad', 'alcalde', 'guardia', 'juez', 'llegar', 'persona', 'tren', 'ayer', 'noticia']
# TOPIC 2
# ['fuerza', 'color', 'piedra', 'agua', 'colera', 'explosion', 'aire', 'metro', 'cuyo', 'cien', 'casa', 'calor', 'edificio', 'taller', 'viento']
# TOPIC 3
# ['España', 'politico', 'gobierno', 'Unidos', 'partido', 'Francia', 'conservador', 'español', 'extranjero', 'periodico', 'tratado', 'publicar', 'caso', 'pais', 'cambio']
# TOPIC 4
# ['impuesto', 'articulo', 'derecho', 'pesetas', 'presupuesto', 'consumo', 'producto', 'administracion', 'gasto', 'pagar', 'clase', 'industrial', 'vino', 'ingreso', 'servicio']
# TOPIC 5
# ...

# %%
timespan_3.assign_topics(["machines", "government", "infrastructure", "international politics", "taxes", "random", "fashion", "international politics", "sales", "event","theatre", "family", "politics", "war"])
l.PL.plot_num_of_articles_per_topic(timespan_3)
timespan_3.save()
# Out:
# Keyword gasolina most likely belongs to topics :
#   - TAXES : topic(s) 4
#   - EVENT : topic(s) 9
# Keyword bencina most likely belongs to topics :
#   - INFRASTRUCTURE : topic(s) 2
#   - FAMILY : topic(s) 11
# Keyword petroleo most likely belongs to topics :
#   - MACHINES : topic(s) 0
#   - INFRASTRUCTURE : topic(s) 2
#   - TAXES : topic(s) 4
#   - GOVERNMENT : topic(s) 1

# %% [markdown]
# ### Fourth time period : 1900-1910

# %%
timespan_4 = l.PR.Timespan(df, "gasoline", "sp", 3)
# Out:
# Timespan from 1900 to 1909 has 1422 articles.
# Successfully loaded model.
# TOPIC 0
# ['idem', 'agua', 'metro', 'tierra', 'alcohol', 'gramo', 'color', 'blanco', 'mano', 'hombre', 'mundo', 'materia', 'kilo', 'suelo', 'dejar']
# TOPIC 1
# ['ministro', 'ayer', 'señor', 'calle', 'noche', 'general', 'obrero', 'Jose', 'comision', 'jefe', 'civil', 'liberal', 'Madrid', 'herido', 'toro']
# TOPIC 2
# ['vender', 'barato', 'precio', 'casa', 'Madrid', 'desear', 'traje', 'modelo', 'piel', 'ceder', 'falda', 'traspasar', 'pral', 'cabello', 'bonito']
# TOPIC 3
# ['gobierno', 'pesetas', 'España', 'obra', 'proyecto', 'fuerza', 'tiempo', 'trabajo', 'Congreso', 'puesto', 'caso', 'presupuesto', 'globo', 'pais', 'hablar']

# %%
timespan_4.assign_topics(["production", "workers", "sales", "government"])
l.PL.plot_num_of_articles_per_topic(timespan_4)
timespan_4.save()
# Out:
# Keyword gasolina most likely belongs to topics :
#   - SALES : topic(s) 2
#   - GOVERNMENT : topic(s) 3
#   - PRODUCTION : topic(s) 0
#   - WORKERS : topic(s) 1
# Keyword bencina most likely belongs to topics :
#   - PRODUCTION : topic(s) 0
# Keyword petroleo most likely belongs to topics :
#   - SALES : topic(s) 2
#   - PRODUCTION : topic(s) 0
#   - WORKERS : topic(s) 1

# %% [markdown]
# ### Fifth time period : 1910-1920

# %%
timespan_5 = l.PR.Timespan(df, "gasoline", "sp", 4)
# Out:
# Timespan from 1910 to 1919 has 1568 articles.
# Successfully loaded model.
# TOPIC 0
# ['noticia', 'general', 'ayer', 'pais', 'buque', 'millón', 'periodico', 'mañana', 'puerto', 'guerra', 'nota', 'Francia', 'grupo', 'español', 'Marina']
# TOPIC 1
# ['hora', 'noche', 'muerto', 'llegar', 'vapor', 'tren', 'mujer', 'salir', 'soldado', 'viaje', 'Policia', 'herido', 'aviador', 'metro', 'poner']
# TOPIC 2
# ['Jose', 'doña', 'calle', 'medio', 'Garcia', 'Maria', 'Manuel', 'Antonio', 'Francisco', 'Luis', 'Lopez', 'obra', 'cuarto', 'Perez', 'Rodriguez']
# TOPIC 3
# ['idem', 'toro', 'premio', 'estocada', 'Ídem', 'Sevilla', 'bicho', 'serie', 'faena', 'corrida', 'doctor', 'cadaver', 'Centro', 'maestro', 'pinchazo']
# TOPIC 4
# ['barato', 'cocina', 'esquina', 'vendo', 'Herradores', 'Felipe', 'Casa', 'agua', 'precio', 'sistema', 'Neri', 'cent', 'Plaza', 'endo', 'petroleo']
# TOPIC 5
# ...

# %%
timespan_5.assign_topics(["newspaper", "travel", "real estate", "bullfight", "sales", "war", "government", "random", "sales"])
l.PL.plot_num_of_articles_per_topic(timespan_5)
timespan_5.save()
# Out:
# Keyword gasolina most likely belongs to topics :
#   - SALES : topic(s) 4, 8
#   - GOVERNMENT : topic(s) 6
#   - TRAVEL : topic(s) 1
# Keyword bencina most likely belongs to topics :
#   - SALES : topic(s) 4, 8
#   - WAR : topic(s) 5
#   - TRAVEL : topic(s) 1
# Keyword petroleo most likely belongs to topics :
#   - SALES : topic(s) 4, 8
#   - NEWSPAPER : topic(s) 0

# %% [markdown]
# ### Sixth time period : 1920 onwards

# %%
timespan_6 = l.PR.Timespan(df, "gasoline", "sp", 5)
# Out:
# Timespan from 1920 to 1933 has 3478 articles.
# Successfully loaded model.
# TOPIC 0
# ['gobernador', 'civil', 'obrero', 'alcalde', 'autoridad', 'huelga', 'ciudad', 'puerto', 'presidente', 'visitar', 'Barcelona', 'Exposicion', 'numeroso', 'acto', 'viaje']
# TOPIC 1
# ['calle', 'lesión', 'grave', 'casa', 'guardia', 'vecino', 'pronostico', 'automovil', 'herido', 'juez', 'herida', 'Juzgado', 'cayo', 'detener', 'producir']
# TOPIC 2
# ['partido', 'equipo', 'toro', 'idem', 'Avila', 'jugar', 'carrera', 'campeonato', 'faena', 'Club', 'azul', 'jugador', 'fanego', 'muleta', 'torero']
# TOPIC 3
# ['pobre', 'mano', 'poner', 'traje', 'negro', 'rico', 'color', 'correr', 'blanco', 'rojo', 'moderno', 'paso', 'clase', 'frio', 'petroleo']
# TOPIC 4
# ['coronel', 'general', 'tropa', 'enemigo', 'jefe', 'soldado', 'teniente', 'quie', 'Directorio', 'alto', 'rebelde', 'militar', 'fuerza', 'Guerra', 'Melilla']
# TOPIC 5
# ...

# %%
timespan_6.assign_topics(["government", "crime", "bullfight", "fashion", "military", "politics", "news", "random", "production", "theatre", "airplanes", "stock", "economy", "sales"])
l.PL.plot_num_of_articles_per_topic(timespan_6)
timespan_6.save()
# Out:
# Keyword gasolina most likely belongs to topics :
#   - CRIME : topic(s) 1
#   - AIRPLANES : topic(s) 10
#   - FASHION : topic(s) 3
#   - MILITARY : topic(s) 4
#   - SALES : topic(s) 13
#   - PRODUCTION : topic(s) 8
#   - POLITICS : topic(s) 5
# Keyword bencina most likely belongs to topics :
#   - FASHION : topic(s) 3
#   - CRIME : topic(s) 1
# Keyword petroleo most likely belongs to topics :
#   - AIRPLANES : topic(s) 10
#   - FASHION : topic(s) 3
#   - PRODUCTION : topic(s) 8
#   - ECONOMY : topic(s) 12
#   - CRIME : topic(s) 1
#   - SALES : topic(s) 13
#   - POLITICS : topic(s) 5
#   - STOCK : topic(s) 11

# %% [markdown]
# ## Overall top 10 topics

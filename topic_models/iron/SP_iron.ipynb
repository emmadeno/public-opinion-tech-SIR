# %% [markdown]
# # Spain topic analysis - Iron

# %% [markdown]
# #### 0. Dependencies and Setup

# %%
import sys
sys.path.insert(0, '../..')
import lib as l

# %%
df = l.U.load_df("Spain", keyword="iron", is_parent=False)
# Out:
# Loaded data from Spain, took 5.22 seconds
# Dataset has size (15413, 3) and columns ['date' 'article' 'lemmas']

# %%
l.PL.plot_articles_over_time(df, "iron")

# %%
l.PL.plot_occurences(df, "iron", l.C.IRON["sp"])

# %% [markdown]
# ## Analyze topic modelling

# %% [markdown]
# ### First time period : 1860-1880

# %%
timespan_1 = l.PR.Timespan(df, "iron", "sp", 0)
# Out:
# Timespan from 1867 to 1879 has 2706 articles.
# Successfully loaded model.
# TOPIC 0
# ['teatro', 'mujer', 'autor', 'toro', 'padre', 'artista', 'escena', 'publico', 'obra', 'acto', 'cuadro', 'casa', 'madre', 'calle', 'medio']
# TOPIC 1
# ['partido', 'Gobierno', 'gobierno', 'ministro', 'derecho', 'señor', 'politico', 'libertad', 'republicano', 'colega', 'proyecto', 'periodico', 'articulo', 'diputado', 'cuestion']
# TOPIC 2
# ['frasco', 'farmacia', 'precio', 'trapo', 'Doña', 'hila', 'caja', 'vender', 'estomago', 'curar', 'calle', 'afección', 'pildora', 'sangre', 'botica']
# TOPIC 3
# ['vida', 'cuyo', 'metro', 'agua', 'mundo', 'tiempo', 'trabajo', 'tierra', 'idea', 'hombre', 'mano', 'industria', 'valor', 'tanto', 'siglo']
# TOPIC 4
# ['ayer', 'carlista', 'general', 'provincia', 'Jose', 'nombrar', 'gobernador', 'distrito', 'Madrid', 'oficial', 'jefe', 'civil', 'coronel', 'Barcelona', 'capital']
# TOPIC 5
# ['ejercito', 'llegar', 'Francia', 'Paris', 'soldado', 'francés', 'tropa', 'carta', 'franz', 'enemigo', 'hora', 'fuerza', 'fuego', 'salir', 'pasar']

# %%
timespan_1.assign_topics(["theatre", "politics", "medicine", "production", "government", "war"])
l.PL.plot_num_of_articles_per_topic(timespan_1)
timespan_1.save()
# Out:
# Keyword hierro most likely belongs to topics :
#   - MEDICINE : topic(s) 2
#   - PRODUCTION : topic(s) 3
#   - WAR : topic(s) 5
#   - GOVERNMENT : topic(s) 4

# %% [markdown]
# ### Second time period : 1880-1890

# %%
timespan_2 = l.PR.Timespan(df, "iron", "sp", 1)
# Out:
# Timespan from 1880 to 1889 has 2515 articles.
# Successfully loaded model.
# TOPIC 0
# ['pais', 'España', 'guerra', 'creer', 'necesidad', 'venir', 'tiempo', 'derecho', 'caso', 'dejar', 'crisis', 'fuerza', 'politico', 'situacion', 'poder']
# TOPIC 1
# ['casa', 'puerta', 'hora', 'cuadro', 'familia', 'marido', 'noche', 'hijo', 'esperar', 'conde', 'calle', 'novela', 'llevar', 'caballero', 'señor']
# TOPIC 2
# ['toro', 'Juan', 'salir', 'salio', 'corrida', 'soltar', 'palo', 'Salvador', 'duque', 'policia', 'crimen', 'llego', 'caballo', 'premio', 'cara']
# TOPIC 3
# ['mujer', 'hombre', 'amor', 'vida', 'padre', 'cosa', 'mundo', 'poeta', 'alma', 'palabra', 'mano', 'Dios', 'querer', 'pobre', 'libro']
# TOPIC 4
# ['agua', 'metro', 'tierra', 'aire', 'maquina', 'altura', 'electrico', 'corriente', 'globo', 'atmosfera', 'escalera', 'hilo', 'extremo', 'puente', 'calor']
# TOPIC 5
# ['señor', 'ministro', 'sesion', 'gobierno', 'proyecto', 'diputado', 'partido', 'Consejo', 'comision', 'marqu', 'Congreso', 'Canovas', 'Sagasta', 'Camara', 'discurso']
# TOPIC 6
# ['pueblo', 'hecho', 'español', 'publico', 'grupo', 'ultimo', 'autor', 'mente', 'seguro', 'persona', 'duda', 'justicia', 'empezar', 'lucha', 'distinto']
# TOPIC 7
# ['pesetas', 'millón', 'comercio', 'valor', 'provincia', 'vino', 'Sociedad', 'gasto', 'pagar', 'ferrocarril', 'articulo', 'aumento', 'producto', 'cantidad', 'general']
# TOPIC 8
# ['ayer', 'calle', 'idem', 'teatro', 'anoche', 'Madrid', 'Jose', 'numero', 'guardia', 'Manuel', 'acto', 'distrito', 'Casa', 'mañana', 'noche']
# TOPIC 9
# ['sello', 'reactivo', 'alterado', 'pureza', 'loduro', 'ACEITE', 'nulo', 'debilitada', 'terapeutico', 'constitución', 'impuro', 'Pildoras', 'organismo', 'estimular', 'irritante']
# TOPIC 10
# ['HIERRO', 'Hierro', 'Vino', 'carne', 'Anemia', 'Sangre', 'sangre', 'reparador', 'estomago', 'Quina', 'Aroud', 'empobrecido', 'medica', 'Afecciones', 'Energia']
# TOPIC 11
# ['noticia', 'general', 'periodico', 'autoridad', 'orden', 'recibir', 'jefe', 'gobernador', 'ministro', 'ayer', 'militar', 'oficial', 'llegar', 'buque', 'telegrama']
# TOPIC 12
# ['fabrica', 'centro', 'taller', 'America', 'obrero', 'completo', 'mina', 'enviar', 'pieza', 'objeto', 'masa', 'terreno', 'trabajo', 'materia', 'industria']
# TOPIC 13
# ['precio', 'vender', 'Madrid', 'pesetas', 'medio', 'frasco', 'principal', 'pral', 'botica', 'clase', 'caja', 'surtido', 'calle', 'casa', 'mueble']

# %%
timespan_2.assign_topics(["government", "family", "bullfight", "literature", "machines", "politics", "public interest", "stock", "theatre", "medicine", "medicine", "newspaper", "factories", "sales"])
l.PL.plot_num_of_articles_per_topic(timespan_2)
timespan_2.save()
# Out:
# Keyword hierro most likely belongs to topics :
#   - MEDICINE : topic(s) 9, 10
#   - SALES : topic(s) 13
#   - MACHINES : topic(s) 4
#   - STOCK : topic(s) 7
#   - FAMILY : topic(s) 1
#   - FACTORIES : topic(s) 12
#   - LITERATURE : topic(s) 3

# %% [markdown]
# ### Third time period : 1890-1900

# %%
timespan_3 = l.PR.Timespan(df, "iron", "sp", 2)
# Out:
# Timespan from 1890 to 1899 has 2853 articles.
# Successfully loaded model.
# TOPIC 0
# ['obrero', 'provincia', 'trabajo', 'Barcelona', 'buque', 'puerto', 'Cadiz', 'huelga', 'regimiento', 'ingeniero', 'soldado', 'pesetas', 'pago', 'ción', 'seccion']
# TOPIC 1
# ['tiempo', 'llegar', 'hombre', 'venir', 'cosa', 'querer', 'dejar', 'momento', 'haber', 'entrar', 'decir', 'obra', 'poder', 'palabra', 'pasar']
# TOPIC 2
# ['casa', 'puerta', 'maquina', 'electrico', 'hora', 'vender', 'madera', 'calle', 'joven', 'mirar', 'piedra', 'pral', 'alma', 'cama', 'reloj']
# TOPIC 3
# ['pesetas', 'idem', 'Jose', 'Garcia', 'Manuel', 'Antonio', 'Francisco', 'Fernandez', 'Lopez', 'Juan', 'hijo', 'Perez', 'Gonzalez', 'Madrid', 'medio']
# TOPIC 4
# ['toro', 'Hernia', 'peligro', 'caballo', 'corrida', 'producir', 'operacion', 'triste', 'voluntad', 'superior', 'energia', 'vida', 'sistema', 'palo', 'ventaja']
# TOPIC 5
# ['ayer', 'ministro', 'general', 'gobierno', 'noche', 'señor', 'mañana', 'Cuba', 'comision', 'noticia', 'partido', 'jefe', 'civil', 'Madrid', 'numero']

# %%
timespan_3.assign_topics(["workers", "random", "sales", "random", "bullfight", "international politics"])
l.PL.plot_num_of_articles_per_topic(timespan_3)
timespan_3.save()
# Out:
# Keyword hierro most likely belongs to topics :
#   - SALES : topic(s) 2
#   - WORKERS : topic(s) 0
#   - BULLFIGHT : topic(s) 4

# %% [markdown]
# ### Fourth time period : 1900-1910

# %%
timespan_4 = l.PR.Timespan(df, "iron", "sp", 3)
# Out:
# Timespan from 1900 to 1909 has 3193 articles.
# Successfully loaded model.
# TOPIC 0
# ['vida', 'hombre', 'tiempo', 'agua', 'tierra', 'mano', 'cosa', 'mundo', 'libro', 'querer', 'vivir', 'alma', 'dejar', 'amor', 'viejo']
# TOPIC 1
# ['precio', 'vender', 'casa', 'Madrid', 'barato', 'pral', 'clase', 'farmacia', 'desear', 'curar', 'pesetas', 'venta', 'mueble', 'gratis', 'enfermedad']
# TOPIC 2
# ['gobernador', 'llegar', 'mañana', 'jefe', 'militar', 'TELÉGRAFO', 'noticia', 'autoridad', 'persona', 'quedar', 'civil', 'casa', 'ruso', 'policia', 'guardia']
# TOPIC 3
# ['Jose', 'ayer', 'toro', 'medio', 'noche', 'Madrid', 'teatro', 'Garcia', 'calle', 'Manuel', 'cuarto', 'Maria', 'fiesta', 'Antonio', 'señora']
# TOPIC 4
# ['ministro', 'gobierno', 'señor', 'presidente', 'comision', 'proyecto', 'Consejo', 'asunto', 'general', 'España', 'sesion', 'Congreso', 'diputado', 'cion', 'politico']

# %%
timespan_4.assign_topics(["literature", "sales", "military", "entertainment", "politics"])
l.PL.plot_num_of_articles_per_topic(timespan_4)
timespan_4.save()
# Out:
# Keyword hierro most likely belongs to topics :
#   - SALES : topic(s) 1
#   - LITERATURE : topic(s) 0
#   - MILITARY : topic(s) 2

# %% [markdown]
# ### Fifth time period : 1910-1920

# %%
timespan_5 = l.PR.Timespan(df, "iron", "sp", 4)
# Out:
# Timespan from 1910 to 1919 has 1879 articles.
# Successfully loaded model.
# TOPIC 0
# ['idem', 'Jose', 'Garcia', 'Francisco', 'Manuel', 'calle', 'Antonio', 'Lopez', 'Luis', 'Perez', 'Fernandez', 'Gonzalez', 'Rodriguez', 'Juzgado', 'doña']
# TOPIC 1
# ['señora', 'viuda', 'duque', 'Victoria', 'duquesa', 'Isabel', 'condesa', 'hija', 'señorita', 'conde', 'palacio', 'marquesa', 'Reina', 'premio', 'marqu']
# TOPIC 2
# ['España', 'español', 'pais', 'pueblo', 'guerra', 'nacional', 'politico', 'politica', 'Francia', 'opinion', 'cion', 'poder', 'deber', 'crisis', 'creer']
# TOPIC 3
# ['vender', 'vendo', 'barato', 'precio', 'pesetas', 'endo', 'plata', 'mueble', 'Razon', 'Conde', 'ompro', 'tiendar', 'agua', 'cama', 'Monte']
# TOPIC 4
# ['ministro', 'ayer', 'presidente', 'obrero', 'proyecto', 'jefe', 'huelga', 'Consejo', 'Comision', 'señor', 'gobierno', 'Gobierno', 'diputado', 'alcalde', 'gobernador']
# TOPIC 5
# ['alemán', 'enemigo', 'tropa', 'ruso', 'ataque', 'frente', 'aliado', 'alemar', 'noche', 'prisionero', 'oficial', 'norte', 'ejercito', 'guerra', 'Alemania']
# TOPIC 6
# ['calle', 'casa', 'juez', 'coche', 'automovil', 'plaza', 'viajero', 'tranvia', 'suceso', 'tren', 'Policia', 'dueño', 'paseo', 'caballo', 'paso']
# TOPIC 7
# ['medio', 'cuarto', 'misa', 'estreno', 'doble', 'exito', 'predicar', 'doña', 'acto', 'Maria', 'partido', 'teatro', 'tanto', 'funcion', 'rojo']
# TOPIC 8
# ['llegar', 'amigo', 'tenia', 'salir', 'hora', 'ciudad', 'poner', 'moro', 'habiar', 'llamar', 'muerto', 'victima', 'suelo', 'herido', 'entrar']
# TOPIC 9
# ['vida', 'hombre', 'mundo', 'viejo', 'amor', 'cosa', 'libro', 'siglo', 'mujer', 'obra', 'alma', 'querer', 'espiritu', 'Dios', 'idea']
# TOPIC 10
# ['millón', 'trabajo', 'pesetas', 'precio', 'trigo', 'fabrica', 'condición', 'obra', 'clase', 'estudio', 'actual', 'industria', 'carbon', 'cantidad', 'gasto']
# TOPIC 11
# ['toro', 'estocada', 'faena', 'bicho', 'muleta', 'pinchazo', 'pase', 'Ovacion', 'oreja', 'diestro', 'valiente', 'torero', 'corrida', 'torear', 'bravo']

# %%
timespan_5.assign_topics(["random", "aristocracy", "politics", "sales", "givernment", "war", "travel", "theatre", "crime", "literature", "production", "bullfight"])
l.PL.plot_num_of_articles_per_topic(timespan_5)
timespan_5.save()
# Out:
# Keyword hierro most likely belongs to topics :
#   - SALES : topic(s) 3
#   - PRODUCTION : topic(s) 10
#   - LITERATURE : topic(s) 9
#   - CRIME : topic(s) 8
#   - WAR : topic(s) 5

# %% [markdown]
# ### Sixth time period : 1920 onwards

# %%
timespan_6 = l.PR.Timespan(df, "iron", "sp", 5)
# Out:
# Timespan from 1920 to 1933 has 2267 articles.
# Successfully loaded model.
# TOPIC 0
# ['vida', 'obra', 'señor', 'español', 'tierra', 'libro', 'palabra', 'decir', 'cosa', 'idea', 'mundo', 'pensar', 'unico', 'venir', 'sentir']
# TOPIC 1
# ['mujer', 'mano', 'padre', 'teatro', 'puerta', 'arte', 'hijo', 'viejo', 'amor', 'hombre', 'casa', 'madre', 'alma', 'artista', 'señora']
# TOPIC 2
# ['vendo', 'pesetas', 'surtido', 'endo', 'precio', 'vender', 'mueble', 'barato', 'Bernardo', 'dorado', 'Consulta', 'Telefono', 'Razon', 'cama', 'Conde']
# TOPIC 3
# ['Gobierno', 'fuerza', 'pais', 'Francia', 'guerra', 'llegar', 'Alemania', 'francés', 'Italia', 'Paris', 'liar', 'soldado', 'tropa', 'libertad', 'pueblo']
# TOPIC 4
# ['pesetas', 'proyecto', 'Consejo', 'ministro', 'idem', 'actual', 'millón', 'huelga', 'ministerio', 'servicio', 'decreto', 'industria', 'cion', 'mercado', 'cantidad']
# TOPIC 5
# ['ayer', 'calle', 'Madrid', 'Jose', 'civil', 'acto', 'alcalde', 'señor', 'general', 'celebrar', 'gobernador', 'doctor', 'doña', 'Garcia', 'herido']
# TOPIC 6
# ['idem', 'medio', 'toro', 'cuarto', 'partido', 'equipo', 'muleta', 'torero', 'faena', 'acción', 'cambio', 'exito', 'Bolsa', 'Banco', 'novillo']

# %%
timespan_6.assign_topics(["literature", "theatre", "sales", "international politics", "production", "government", "bullfight"])
l.PL.plot_num_of_articles_per_topic(timespan_6)
timespan_6.save()
# Out:
# Keyword hierro most likely belongs to topics :
#   - SALES : topic(s) 2
#   - THEATRE : topic(s) 1
#   - INTERNATIONAL POLITICS : topic(s) 3
#   - PRODUCTION : topic(s) 4

# %% [markdown]
# ## Overall top 10 topics

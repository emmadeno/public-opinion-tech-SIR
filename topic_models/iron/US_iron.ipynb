# %% [markdown]
# # USA topic analysis - Iron

# %% [markdown]
# #### 0. Dependencies and Setup

# %%
import sys
sys.path.insert(0, '../..')
import lib as l

# %%
df = l.U.load_df("USA", keyword="iron", is_parent=False)
# Out:
# Loaded data from USA, took 32.126 seconds
# Dataset has size (49632, 3) and columns ['date' 'article' 'lemmas']

# %%
l.PL.plot_articles_over_time(df, "iron")

# %%
l.PL.plot_occurences(df, "iron", l.C.IRON["eng"])

# %% [markdown]
# ## Analyze topic modelling

# %% [markdown]
# ### First time period : 1830-1850

# %%
timespan_1 = l.PR.Timespan(df, "iron", "eng", 0)
# Out:
# Timespan from 1836 to 1849 has 4652 articles.
# Successfully loaded model.
# TOPIC 0
# ['cure', 'disease', 'stricture', 'medicine', 'remedy', 'tooth', 'treatment', 'bottle', 'medical', 'pain', 'complaint', 'Pills', 'physician', 'consult', 'patient']
# TOPIC 1
# ['Court', 'defendant', 'plaintiff', 'prisoner', 'arrest', 'Judge', 'jury', 'witness', 'night', 'court', 'commit', 'yesterday', 'steal', 'house', 'name']
# TOPIC 2
# ['lira', 'tbat', 'Ilia', 'laat', 'tint', 'ilia', 'till', 'lint', 'thai', 'liar', 'raid', 'light', 'rail', 'thin', 'lata']
# TOPIC 3
# ['tion', 'water', 'heat', 'tree', 'work', 'pleasure', 'beautiful', 'tlie', 'hich', 'ment', 'thousand', 'mile', 'machine', 'safety', 'race']
# TOPIC 4
# ['inch', 'stove', 'furniture', 'foot', 'township', 'auction', 'table', 'Stove', 'Cutlery', 'silk', 'room', 'mahogany', 'diameter', 'pound', 'Paper']
# TOPIC 5
# ['cabin', 'packet', 'freight', 'apply', 'passage', 'Captain', 'accommodation', 'regular', 'ticket', 'sail', 'board', 'LINE', 'pier', 'sailing', 'ship']
# TOPIC 6
# ['people', 'government', 'England', 'church', 'political', 'cheer', 'Lord', 'nation', 'world', 'great', 'influence', 'minister', 'feeling', 'France', 'moral']
# TOPIC 7
# ['July', 'Ohio', 'Troy', 'Norwich', 'Yoik', 'Philadelphia', 'Connecticut', 'Vork', 'Michigan', 'Smith', 'Arnold', 'Montreal', 'Buffalo', 'White', 'Carroll']
# TOPIC 8
# ['market', 'wheat', 'bale', 'demand', 'flour', 'Bank', 'export', 'bank', 'crop', 'cotton', 'bbls', 'quotation', 'quote', 'stock', 'bushel']
# TOPIC 9
# ['brig', 'NYork', 'bark', 'Schr', 'Mary', 'Boston', 'schr', 'Baltimore', 'Brig', 'Liverpool', 'ship', 'Ship', 'April', 'Sept', 'Orleans']
# TOPIC 10
# ['resolution', 'Mexico', 'whig', 'Senate', 'vote', 'question', 'committee', 'bill', 'Texas', 'General', 'report', 'government', 'President', 'treaty', 'Congress']
# TOPIC 11
# ['assortment', 'style', 'Broadway', 'subscriber', 'establishment', 'wholesale', 'cash', 'cheap', 'respectfully', 'retail', 'article', 'Watches', 'street', 'sale', 'superior']
# TOPIC 12
# ['atreet', 'thia', 'Lock', 'hare', 'moat', 'aale', 'eery', 'thoae', 'Bowery', 'Broadway', 'Madame', 'alao', 'hair', 'yeara', 'Spring']

# %%
timespan_1.assign_topics(["medicine", "crime", "random", "machines", "furniture", "boats", "politics", "cities", "stock", "boats", "politics", "sales", "random"])
l.PL.plot_num_of_articles_per_topic(timespan_1)
timespan_1.save()
# Out:
# Keyword iron most likely belongs to topics :
#   - FURNITURE : topic(s) 4
#   - MACHINES : topic(s) 3
#   - STOCK : topic(s) 8
#   - SHIPS : topic(s) 9
#   - POLITICS : topic(s) 6, 10
#   - CRIME : topic(s) 1
#   - BOATS : topic(s) 5
#   - SAKES : topic(s) 11

# %% [markdown]
# ### Second time period : 1850-1855

# %%
timespan_2 = l.PR.Timespan(df, "iron", "eng", 1)
# Out:
# Timespan from 1850 to 1854 has 4013 articles.
# Successfully loaded model.
# TOPIC 0
# ['government', 'people', 'whig', 'think', 'shall', 'question', 'party', 'come', 'great', 'duty', 'vote', 'officer', 'States', 'bill', 'subject']
# TOPIC 1
# ['thia', 'tbat', 'thai', 'moat', 'thla', 'bare', 'tint', 'light', 'whioh', 'till', 'lira', 'laat', 'treat', 'lata', 'drama']
# TOPIC 2
# ['bbls', 'market', 'Railroad', 'total', 'bale', 'stock', 'road', 'Company', 'bond', 'Ohio', 'barrel', 'Bank', 'cent', 'Erie', 'demand']
# TOPIC 3
# ['street', 'Broadway', 'apply', 'furniture', 'avenue', 'SALE', 'room', 'house', 'sale', 'story', 'mahogany', 'rosewood', 'parlor', 'atreet', 'pier']
# TOPIC 4
# ['NYork', 'brig', 'bark', 'Boston', 'Philadelphia', 'Schr', 'Mary', 'ship', 'Liverpool', 'Sept', 'Bark', 'Ship', 'Baltimore', 'June', 'Smith']
# TOPIC 5
# ['situation', 'respectable', 'reference', 'woman', 'young', 'want', 'cook', 'chambermaid', 'family', 'SITUATION', 'waiter', 'apply', 'washer', 'housework', 'GIRL']

# %%
timespan_2.assign_topics(["politics", "random", "stock", "sales", "boats", "hiring"])
l.PL.plot_num_of_articles_per_topic(timespan_2)
timespan_2.save()
# Out:
# Keyword iron most likely belongs to topics :
#   - HIRING : topic(s) 5
#   - STOCK : topic(s) 2
#   - SALES : topic(s) 3
#   - POLITICS : topic(s) 0
#   - BOATS : topic(s) 4

# %% [markdown]
# ### Third time period : 1855-1860

# %%
timespan_3 = l.PR.Timespan(df, "iron", "eng", 2)
# Out:
# Timespan from 1855 to 1859 has 6000 articles.
# Successfully loaded model.
# TOPIC 0
# ['street', 'apply', 'gentleman', 'room', 'house', 'modern', 'avenue', 'location', 'single', 'board', 'rent', 'story', 'atreet', 'inquire', 'premise']
# TOPIC 1
# ['government', 'people', 'shall', 'question', 'report', 'vote', 'States', 'party', 'subject', 'State', 'member', 'Governor', 'right', 'duty', 'United']
# TOPIC 2
# ['street', 'Broadway', 'reward', 'horse', 'price', 'piano', 'wagon', 'warrant', 'sound', 'harness', 'cent', 'corner', 'style', 'retail', 'office']
# TOPIC 3
# ['brig', 'NYork', 'bark', 'Boston', 'John', 'ship', 'Mary', 'Schr', 'port', 'Baltimore', 'Liverpool', 'Brig', 'Bark', 'Havana', 'Ship']
# TOPIC 4
# ['bare', 'thai', 'July', 'hare', 'April', 'thla', 'loot', 'laat', 'mora', 'tbla', 'March', 'moot', 'tbia', 'tier', 'thin']
# TOPIC 5
# ['lata', 'rata', 'will', 'atraat', 'wall', 'root', 'abort', 'alao', 'lira', 'aire', 'rail', 'treat', 'rood', 'raid', 'bona']
# TOPIC 6
# ['situation', 'reference', 'woman', 'SITUATION', 'respectable', 'cook', 'chambermaid', 'young', 'girl', 'GIRL', 'objection', 'washer', 'housework', 'waiter', 'washing']
# TOPIC 7
# ['rosewood', 'furniture', 'mahogany', 'chair', 'auction', 'mirror', 'marble', 'carpet', 'table', 'auctioneer', 'bedstead', 'parlor', 'china', 'painting', 'glass']
# TOPIC 8
# ['come', 'body', 'church', 'think', 'death', 'night', 'time', 'Austria', 'cable', 'hear', 'look', 'prisoner', 'great', 'life', 'know']
# TOPIC 9
# ['bbls', 'market', 'total', 'funeral', 'bbla', 'Central', 'Railroad', 'bushel', 'demand', 'Total', 'dull', 'bale', 'stock', 'Bank', 'cent']
# TOPIC 10
# ['cabin', 'passage', 'freight', 'pier', 'Wednesday', 'Saturday', 'steamship', 'Liverpool', 'river', 'Capt', 'passenger', 'sail', 'clipper', 'ship', 'commander']

# %%
timespan_3.assign_topics(["real estate", "government", "sales", "ships", "random", "random", "hiring", "furniture", "crime", "stock", "boats"])
l.PL.plot_num_of_articles_per_topic(timespan_3)
timespan_3.save()
# Out:
# Keyword iron most likely belongs to topics :
#   - HIRING : topic(s) 6
#   - FURNITURE : topic(s) 7
#   - STOCK : topic(s) 9
#   - BOATS : topic(s) 10
#   - CRIME : topic(s) 8
#   - REAL ESTATE : topic(s) 0
#   - SALES : topic(s) 2
#   - GOVERNMENT : topic(s) 1
#   - SHIPS : topic(s) 3

# %% [markdown]
# ### Fourth time period : 1860-1865

# %%
timespan_4 = l.PR.Timespan(df, "iron", "eng", 3)
# Out:
# Timespan from 1860 to 1864 has 6638 articles.
# Successfully loaded model.
# TOPIC 0
# ['street', 'apply', 'avenue', 'Board', 'reference', 'situation', 'SITUATION', 'family', 'woman', 'room', 'gentleman', 'respectable', 'cook', 'want', 'Herald']
# TOPIC 1
# ['rebel', 'General', 'government', 'army', 'enemy', 'people', 'force', 'report', 'regiment', 'vessel', 'officer', 'shall', 'tbat', 'time', 'troop']
# TOPIC 2
# ['cabin', 'pier', 'passage', 'Saturday', 'freight', 'Liverpool', 'river', 'London', 'Hamburg', 'York', 'June', 'July', 'payable', 'North', 'April']
# TOPIC 3
# ['NYork', 'John', 'funeral', 'brig', 'bark', 'March', 'invite', 'April', 'Boston', 'ship', 'Schr', 'afternoon', 'Mary', 'port', 'relative']

# %%
timespan_4.assign_topics(["hiring", "war", "boats", "boats"])
l.PL.plot_num_of_articles_per_topic(timespan_4)
timespan_4.save()
# Out:
# Keyword iron most likely belongs to topics :
#   - HIRING : topic(s) 0
#   - BOATS : topic(s) 2, 3
#   - WAR : topic(s) 1

# %% [markdown]
# ### Fifth time period : 1860-1870

# %%
timespan_5 = l.PR.Timespan(df, "iron", "eng", 4)
# Out:
# Timespan from 1865 to 1869 has 7270 articles.
# Successfully loaded model.
# TOPIC 0
# ['reference', 'cook', 'woman', 'family', 'respectable', 'girl', 'WEST', 'situation', 'chambermaid', 'want', 'young', 'SITUATION', 'objection', 'good', 'washing']
# TOPIC 1
# ['NYork', 'Schr', 'brig', 'government', 'report', 'funeral', 'yesterday', 'bark', 'people', 'shall', 'arrive', 'Boston', 'time', 'General', 'April']
# TOPIC 2
# ['street', 'pier', 'avenue', 'Saturday', 'Broadway', 'apply', 'freight', 'passage', 'sale', 'atreet', 'SALE', 'cabin', 'river', 'price', 'Furniture']

# %%
timespan_5.assign_topics(["hiring", "boats", "sales"])
l.PL.plot_num_of_articles_per_topic(timespan_5)
timespan_5.save()
# Out:
# Keyword iron most likely belongs to topics :
#   - HIRING : topic(s) 0
#   - SALES : topic(s) 2
#   - BOATS : topic(s) 1

# %% [markdown]
# ### Sixth time period : 1870-1875

# %%
timespan_6 = l.PR.Timespan(df, "iron", "eng", 5)
# Out:
# Timespan from 1870 to 1874 has 9076 articles.
# Successfully loaded model.
# TOPIC 0
# ['street', 'avenue', 'sale', 'rent', 'SALE', 'Furniture', 'horse', 'Harness', 'sound', 'Broadway', 'apply', 'sell', 'room', 'price', 'trot']
# TOPIC 1
# ['pier', 'Saturday', 'passage', 'ticket', 'currency', 'steerage', 'freight', 'cabin', 'Cabin', 'North', 'gold', 'steamer', 'River', 'Captain', 'Agent']
# TOPIC 2
# ['reference', 'cook', 'woman', 'respectable', 'washing', 'girl', 'WEST', 'family', 'chambermaid', 'housework', 'young', 'EAST', 'situation', 'waitress', 'SITUATION']
# TOPIC 3
# ['funeral', 'government', 'people', 'market', 'relative', 'yesterday', 'report', 'come', 'dull', 'shall', 'quote', 'demand', 'think', 'question', 'invite']
# TOPIC 4
# ['Schr', 'bark', 'brig', 'schr', 'Boston', 'York', 'Bark', 'arrive', 'Providence', 'Philadelphia', 'schrs', 'Liverpool', 'ship', 'Baltimore', 'Sept']

# %%
timespan_6.assign_topics(["sales", "boats", "hirjng", "funeral", "boats"])
l.PL.plot_num_of_articles_per_topic(timespan_6)
timespan_6.save()
# Out:
# Keyword iron most likely belongs to topics :
#   - HIRJNG : topic(s) 2
#   - BOATS : topic(s) 1, 4
#   - FUNERAL : topic(s) 3
#   - SALES : topic(s) 0

# %% [markdown]
# ### Seventh time period : 1975-1880

# %%
timespan_7 = l.PR.Timespan(df, "iron", "eng", 6)
# Out:
# Timespan from 1875 to 1879 has 8236 articles.
# Successfully loaded model.
# TOPIC 0
# ['reference', 'cook', 'woman', 'housework', 'WEST', 'family', 'girl', 'washing', 'respectable', 'chambermaid', 'private', 'washer', 'city', 'GIRL', 'EAST']
# TOPIC 1
# ['bark', 'Schr', 'brig', 'York', 'Sept', 'schr', 'Liverpool', 'Baltimore', 'Bark', 'Steamer', 'sail', 'Boston', 'July', 'arrive', 'Philadelphia']
# TOPIC 2
# ['pier', 'Broadway', 'ticket', 'North', 'apply', 'River', 'street', 'freight', 'rent', 'CITY', 'Saturday', 'office', 'passage', 'Board', 'sale']
# TOPIC 3
# ['quote', 'quiet', 'market', 'dull', 'steady', 'middling', 'bushel', 'government', 'weight', 'demand', 'report', 'corn', 'bond', 'bbls', 'firm']
# TOPIC 4
# ['street', 'funeral', 'Judge', 'invite', 'Court', 'yesterday', 'friend', 'attend', 'tbat', 'know', 'come', 'relative', 'irom', 'witness', 'residence']

# %%
timespan_7.assign_topics(["hiring", "boats", "boats", "production", "funeral"])
l.PL.plot_num_of_articles_per_topic(timespan_7)
timespan_7.save()
# Out:
# Keyword iron most likely belongs to topics :
#   - HIRING : topic(s) 0
#   - FUNERAL : topic(s) 4
#   - BOATS : topic(s) 1, 2
#   - PRODUCTION : topic(s) 3

# %% [markdown]
# ### Eighth time period : 1920-1922

# %%
timespan_8 = l.PR.Timespan(df, "iron", "eng", 7)
# Out:
# Timespan from 1920 to 1922 has 3747 articles.
# Successfully loaded model.
# TOPIC 0
# ['reference', 'room', 'Herald', 'experience', 'family', 'bath', 'position', 'want', 'apartment', 'cook', 'wish', 'game', 'good', 'private', 'play']
# TOPIC 1
# ['Inter', 'first', 'Swift', 'Gold', 'extra', 'bond', 'March', 'Motors', 'Coupon', 'Tono', 'Cons', 'white', 'Land', 'Phil', 'Phlla']
# TOPIC 2
# ['sail', 'strs', 'street', 'arrive', 'barge', 'avenue', 'Port', 'Miss', 'night', 'John', 'know', 'leave', 'foot', 'Germany', 'George']
# TOPIC 3
# ['Steel', 'cent', 'Pacific', 'stock', 'Company', 'deposit', 'Trust', 'market', 'dividend', 'bond', 'Motor', 'Copper', 'company', 'Sugar', 'price']

# %%
timespan_8.assign_topics(["hiring", "companies", "boats", "stock"])
l.PL.plot_num_of_articles_per_topic(timespan_8)
timespan_8.save()
# Out:
# Keyword iron most likely belongs to topics :
#   - COMPANIES : topic(s) 1
#   - STOCK : topic(s) 3
#   - BOATS : topic(s) 2
#   - HIRING : topic(s) 0

# %% [markdown]
# ## Overall top 10 topics

# %%
l.PL.get_top_topics(topics)

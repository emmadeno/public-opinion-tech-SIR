# %% [markdown]
# # France topic analysis - Telephone

# %% [markdown]
# #### 0. Dependencies and Setup

# %%
import sys
sys.path.insert(0, '../..')
import lib as l

# %%
df = l.U.load_df("France", keyword="telephone", is_parent=False)
# Out:
# Loaded data from France, took 12.524 seconds
# Dataset has size (68499, 3) and columns ['date' 'article' 'lemmas']

# %%
l.PL.plot_articles_over_time(df, "telephone")

# %%
l.PL.plot_occurences(df, "telephone", l.C.TELEPHONE["fr"])

# %% [markdown]
# ## Analyze topic modelling

# %% [markdown]
# ### First time period : 1870-1890

# %%
timespan_1 = l.PR.Timespan(df, "telephone", "fr", 0)
# Out:
# Timespan from 1877 to 1889 has 1021 articles.
# Successfully loaded model.
# TOPIC 0
# ['police', 'hier', 'trouver', 'long', 'force', 'mourir', 'lumiere', 'trouve', 'bout', 'curieux', 'falloir', 'charge', 'grâce', 'electriqu', 'commissaire']
# TOPIC 1
# ['mlle', 'course', 'prix', 'gagne', 'theâtre', 'rôle', 'acte', 'representation', 'longueur', 'Mlle', 'piece', 'artiste', 'battre', 'comte', 'scene']
# TOPIC 2
# ['louer', 'Concert', 'notaire', 'ench', 'soir', 'varie', 'mise', 'meuble', 'vendre', 'Dimanches', 'avoue', 'varier', 'prix', 'cirque', 'Entree']
# TOPIC 3
# ['terme', 'Credit', 'fonciere', 'ternie', 'algerien', 'communale', 'Algerien', 'credit', 'mobilier', 'banque', 'liyp', 'Faris', 'clôture', 'gramme', 'Kord']
# TOPIC 4
# ['fonciere', 'serie', 'obligation', 'ottoman', 'valeurs', 'Lyonnaise', 'communale', 'Gener', 'nouv', 'France', 'gramme', 'etablissement', 'nouveau', 'exterieure', 'Transatlantique']
# TOPIC 5
# ...

# %%
timespan_1.assign_topics(["crime", "theatre", "sales", "stock", "international economy", "family", "international economy", "workers", "random", "vacation", "stock", "politics", "real estate"])
l.PL.plot_num_of_articles_per_topic(timespan_1)
timespan_1.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - FAMILY : topic(s) 5
#   - REAL ESTATE : topic(s) 12
#   - STOCK : topic(s) 3, 10
#   - INTERNATIONAL ECONOMY : topic(s) 4, 6
#   - SALES : topic(s) 2
#   - THEATRE : topic(s) 1

# %% [markdown]
# ### Second time period : 1890-1900

# %%
timespan_2 = l.PR.Timespan(df, "telephone", "fr", 1)
# Out:
# Timespan from 1890 to 1899 has 7413 articles.
# Successfully loaded model.
# TOPIC 0
# ['mlle', 'theâtre', 'succe', 'acte', 'representation', 'artiste', 'premiere', 'prix', 'scene', 'soir', 'rôle', 'longueur', 'Mlle', 'musique', 'programme']
# TOPIC 1
# ['soir', 'heure', 'Concert', 'matin', 'theatre', 'concert', 'fete', 'Dimanches', 'revue', 'Jeudis', 'jardin', 'etage', 'Telephone', 'minuit', 'nuit']
# TOPIC 2
# ['fonciere', 'France', 'communale', 'serie', 'etablissement', 'Lyonnaise', 'Gener', 'Paris', 'fusion', 'Lits', 'Lyon', 'canal', 'Generale', 'Panama', 'parisien']
# TOPIC 3
# ['cuisiniere', 'place', 'refer', 'valet', 'reference', 'menage', 'demande', 'desir', 'sach', 'concierge', 'ecrire', 'faire', 'chambre', 'maître', 'cocher']
# TOPIC 4
# ['temps', 'falloir', 'jour', 'chambre', 'politique', 'public', 'bien', 'gouvernement', 'fort', 'France', 'pays', 'depute', 'pouvoir', 'contre', 'côte']
# TOPIC 5
# ...

# %%
timespan_2.assign_topics(["theatre", "theatre", "cities", "hiring", "politics", "politics", "aristocracy", "real estate", "stock", "random", "hotels", "administration"])
l.PL.plot_num_of_articles_per_topic(timespan_2)
timespan_2.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - THEATRE : topic(s) 0, 1
#   - HOTELS : topic(s) 10
#   - REAL ESTATE : topic(s) 7
#   - STOCK : topic(s) 8
#   - ADMINISTRATION : topic(s) 11
#   - HIRING : topic(s) 3

# %% [markdown]
# ### Third time period : 1900-1910

# %%
timespan_3 = l.PR.Timespan(df, "telephone", "fr", 2)
# Out:
# Timespan from 1900 to 1909 has 11369 articles.
# Successfully loaded model.
# TOPIC 0
# ['PARIS', 'hotel', 'terme', 'pari', 'action', 'gramme', 'banque', 'valeur', 'meuble', 'marseille', 'franc', 'tramw', 'paye', 'louer', 'parisien']
# TOPIC 1
# ['comte', 'prix', 'marquis', 'place', 'comtesse', 'mlle', 'baron', 'course', 'longueur', 'mutuel', 'gagner', 'Pari', 'grand', 'baronne', 'vicomte']
# TOPIC 2
# ['faire', 'bien', 'être', 'ministre', 'temps', 'vouloir', 'venir', 'jour', 'falloir', 'voir', 'hier', 'president', 'savoir', 'prendre', 'general']
# TOPIC 3
# ['cuisiniere', 'refer', 'valet', 'place', 'reference', 'menage', 'ecrire', 'sach', 'desir', 'demande', 'verb', 'serv', 'concierge', 'enage', 'cout']
# TOPIC 4
# ['mlle', 'representation', 'revue', 'matinee', 'theâtre', 'acte', 'soir', 'concert', 'heure', 'spectacle', 'Societe', 'comedie', 'succe', 'Gener', 'piece']

# %%
timespan_3.assign_topics(["real estate", "aristocracy", "politics", "hiring", "theatre"])
l.PL.plot_num_of_articles_per_topic(timespan_3)
timespan_3.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - REAL ESTATE : topic(s) 0
#   - ARISTOCRACY : topic(s) 1
#   - THEATRE : topic(s) 4
#   - POLITICS : topic(s) 2

# %% [markdown]
# ### Fourth time period : 1910-1920

# %%
timespan_4 = l.PR.Timespan(df, "telephone", "fr", 3)
# Out:
# Timespan from 1910 to 1919 has 5986 articles.
# Successfully loaded model.
# TOPIC 0
# ['bien', 'être', 'voir', 'vouloir', 'petit', 'temps', 'avoir', 'faire', 'savoir', 'venir', 'rien', 'trop', 'chose', 'homme', 'falloir']
# TOPIC 1
# ['privil', 'banque', 'Credit', 'Tramways', 'Mexique', 'tramway', 'prior', 'parisien', 'action', 'Raffineries', 'Railways', 'Fonciere', 'Buenos', 'Transatlantique', 'Lyonnais']
# TOPIC 2
# ['guerre', 'allemand', 'ministre', 'president', 'contre', 'hier', 'conseil', 'gouvernement', 'paix', 'tion', 'question', 'politique', 'general', 'pays', 'franc']
# TOPIC 3
# ['mlle', 'theâtre', 'matinee', 'revue', 'representation', 'soir', 'acte', 'heure', 'comedie', 'spectacle', 'theâtr', 'soiree', 'succe', 'dimanche', 'artiste']
# TOPIC 4
# ['comte', 'comtesse', 'place', 'marquis', 'refer', 'cuisiniere', 'reference', 'valet', 'prix', 'comtess', 'baron', 'demande', 'vicomte', 'chambre', 'baronne']

# %%
timespan_4.assign_topics(["random", "trains", "war", "theatre", "hiring"])
l.PL.plot_num_of_articles_per_topic(timespan_4)
timespan_4.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - TRAINS : topic(s) 1
#   - HIRING : topic(s) 4
#   - THEATRE : topic(s) 3

# %% [markdown]
# ### Fifth time period : 1920-1925

# %%
timespan_5 = l.PR.Timespan(df, "telephone", "fr", 4)
# Out:
# Timespan from 1920 to 1924 has 7761 articles.
# Successfully loaded model.
# TOPIC 0
# ['bien', 'être', 'jeune', 'voir', 'petit', 'vouloir', 'rien', 'faire', 'savoir', 'femme', 'homme', 'avoir', 'venir', 'passer', 'jamais']
# TOPIC 1
# ['Theâtre', 'mlle', 'matinee', 'revue', 'soir', 'heure', 'representation', 'soiree', 'theâtre', 'dimanche', 'acte', 'Jane', 'spectacle', 'concert', 'repetition']
# TOPIC 2
# ['hôtel', 'confort', 'hotel', 'garage', 'parc', 'Hôtel', 'ordre', 'moderne', 'grand', 'chambre', 'vendre', 'meuble', 'bains', 'jardin', 'cuisine']
# TOPIC 3
# ['comte', 'franc', 'hier', 'marquis', 'comtesse', 'general', 'lieu', 'mlle', 'docteur', 'mort', 'juge', 'Paul', 'heure', 'president', 'prince']
# TOPIC 4
# ['relâche', 'comedie', 'theatre', 'heure', 'gymnase', 'opera', 'Dame', 'mathurin', 'CHAMPS', 'Louis', 'lyrique', 'ELYSEES', 'capucine', 'variete', 'jeudi']
# TOPIC 5
# ...

# %%
timespan_5.assign_topics(["random", "theatre", "real estate", "aristocracy", "theatre", "competiton", "politics", "international", "random"])
l.PL.plot_num_of_articles_per_topic(timespan_5)
timespan_5.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - REAL ESTATE : topic(s) 2
#   - THEATRE : topic(s) 1, 4
#   - INTERNATIONAL : topic(s) 7
#   - ARISTOCRACY : topic(s) 3

# %% [markdown]
# ### Sixth time period : 1925-1930

# %%
timespan_6 = l.PR.Timespan(df, "telephone", "fr", 5)
# Out:
# Timespan from 1925 to 1929 has 10113 articles.
# Successfully loaded model.
# TOPIC 0
# ['bien', 'petit', 'être', 'faire', 'jeune', 'voir', 'avoir', 'femme', 'vouloir', 'livre', 'rien', 'venir', 'savoir', 'homme', 'jour']
# TOPIC 1
# ['mlle', 'franc', 'comtess', 'championnat', 'metre', 'prix', 'comte', 'course', 'club', 'match', 'mutuel', 'miss', 'coupe', 'comtesse', 'Mlle']
# TOPIC 2
# ['remb', 'Nord', 'fonc', 'part', 'Mines', 'Chine', 'Union', 'Copper', 'American', 'serie', 'mine', 'Steel', 'banque', 'Rand', 'Credit']
# TOPIC 3
# ['confort', 'conf', 'reference', 'hotel', 'refer', 'ecrire', 'propriete', 'parc', 'chambre', 'place', 'serv', 'cuisiniere', 'avenue', 'piece', 'menage']
# TOPIC 4
# ['mlle', 'heure', 'Theâtre', 'matinee', 'theâtre', 'soiree', 'comedie', 'soir', 'revue', 'Jean', 'Andre', 'acte', 'representation', 'Pierre', 'spectacle']
# TOPIC 5
# ...

# %%
timespan_6.assign_topics(["random", "aristocracy/competiton", "international", "real estate", "theatre", "war", "politics", "cars"])
l.PL.plot_num_of_articles_per_topic(timespan_6)
timespan_6.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - CARS : topic(s) 7
#   - REAL ESTATE : topic(s) 3
#   - ARISTOCRACY/COMPETITON : topic(s) 1
#   - INTERNATIONAL : topic(s) 2
#   - POLITICS : topic(s) 6
#   - THEATRE : topic(s) 4
#   - WAR : topic(s) 5

# %% [markdown]
# ### Seventh time period : 1930-1935

# %%
timespan_7 = l.PR.Timespan(df, "telephone", "fr", 6)
# Out:
# Timespan from 1930 to 1934 has 9379 articles.
# Successfully loaded model.
# TOPIC 0
# ['franc', 'etat', 'neuf', 'place', 'vendre', 'conduite', 'prix', 'depart', 'cabriolet', 'interieur', 'mars', 'cond', 'viking', 'vente', 'parfaire']
# TOPIC 1
# ['part', 'American', 'Mines', 'Rand', 'Copper', 'Union', 'Chine', 'mine', 'Caoutchoucs', 'Steel', 'Maroc', 'priv', 'Consolidated', 'textile', 'Eagle']
# TOPIC 2
# ['bien', 'être', 'homme', 'faire', 'vouloir', 'temps', 'venir', 'voir', 'chose', 'savoir', 'rien', 'trop', 'petit', 'femme', 'dire']
# TOPIC 3
# ['pathe', 'revue', 'concert', 'heure', 'CINEMA', 'permanent', 'soir', 'cirque', 'Soiree', 'musique', 'soiree', 'Concert', 'salle', 'studio', 'film']
# TOPIC 4
# ['gouvernement', 'politique', 'ministre', 'allemand', 'parti', 'president', 'conseil', 'conference', 'projet', 'guerre', 'pays', 'contre', 'peuple', 'France', 'socialiste']
# TOPIC 5
# ...

# %%
timespan_7.assign_topics(["cars", "international", "random", "films", "politics", "crime", "race", "aristocracy", "theatre", "real estate"])
l.PL.plot_num_of_articles_per_topic(timespan_7)
timespan_7.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - REAL ESTATE : topic(s) 9
#   - CARS : topic(s) 0
#   - INTERNATIONAL : topic(s) 1
#   - FILMS : topic(s) 3
#   - RACE : topic(s) 6
#   - THEATRE : topic(s) 8
#   - ARISTOCRACY : topic(s) 7
#   - POLITICS : topic(s) 4

# %% [markdown]
# ### Eight time period : 1935-1940

# %%
timespan_8 = l.PR.Timespan(df, "telephone", "fr", 7)
# Out:
# Timespan from 1935 to 1939 has 13557 articles.
# Successfully loaded model.
# TOPIC 0
# ['refer', 'Credit', 'Maroc', 'energie', 'fonc', 'reference', 'serv', 'ecrire', 'Paris', 'place', 'serie', 'valet', 'avenue', 'exig', 'menage']
# TOPIC 1
# ['gouvernement', 'ministre', 'allemand', 'politique', 'temps', 'contre', 'guerre', 'tion', 'italien', 'Berlin', 'britannique', 'general', 'conseil', 'Rome', 'France']
# TOPIC 2
# ['mlle', 'prix', 'comte', 'comtesse', 'heure', 'mort', 'grand', 'Jean', 'jeune', 'franc', 'marquis', 'Paris', 'femme', 'petit', 'monsieur']

# %%
timespan_8.assign_topics(["hiring", "politics", "aristocracy"])
l.PL.plot_num_of_articles_per_topic(timespan_8)
timespan_8.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - ARISTOCRACY : topic(s) 2
#   - POLITICS : topic(s) 1
#   - HIRING : topic(s) 0

# %% [markdown]
# ## Overall top 10 topics

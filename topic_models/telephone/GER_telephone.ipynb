# %% [markdown]
# # Germany topic analysis - Telephone

# %% [markdown]
# #### 0. Dependencies and Setup

# %%
import sys
sys.path.insert(0, '../..')
import lib as l

# %%
df = l.U.load_df("Hamburg", keyword="telephone", is_parent=False)
# Out:
# Loaded data from Hamburg, took 3.309 seconds
# Dataset has size (4940, 3) and columns ['date' 'article' 'lemmas']

# %%
l.PL.plot_articles_over_time(df, "telephone")

# %%
l.PL.plot_occurences(df, "telephone", l.C.TELEPHONE["ger"])

# %% [markdown]
# ## Analyze topic modelling

# %% [markdown]
# ### First time period : 1880_1920

# %%
timespan_1 = l.PR.Timespan(df, "telephone", "ger", 0)
# Out:
# Timespan from 1890 to 1919 has 614 articles.
# Successfully loaded model.
# TOPIC 0
# ['Naeh', 'Maedch', 'Maedche', 'vermieten', 'Etage', 'Offerte', 'Zimmer', 'April', 'Naehere', 'verm', 'Wohn', 'Wohnung', 'siir', 'Moebl', 'Saub']
# TOPIC 1
# ['April', 'Februar', 'Antrag', 'Senat', 'Pfund', 'Gramm', 'Abschnitt', 'Grund', 'duerfen', 'erfolgen', 'Bekanntmachung', 'betreffend', 'Menge', 'Million', 'Woche']
# TOPIC 2
# ['stehen', 'sehen', 'wissen', 'Zeuge', 'sprechen', 'fragen', 'koennen', 'ziehen', 'Auge', 'scheinen', 'Welt', 'glauben', 'fahren', 'Gesicht', 'letzter']
# TOPIC 3
# ['Rate', 'Prokura', 'Friedrich', 'Heinrich', 'erloschen', 'Wilhelm', 'Anna', 'Carl', 'Pastor', 'Frau', 'Marie', 'Haftung', 'Otto', 'Standesamt', 'Johann']
# TOPIC 4
# ['Adresse', 'Dezember', 'Pauli', 'Unterricht', 'bieten', 'Eltern', 'Hambg', 'schriftlich', 'Pension', 'Institut', 'Bedingung', 'Verkauf', 'Angebot', 'Juni', 'Elbe']
# TOPIC 5
# ['Juli', 'Oktober', 'ferner', 'September', 'laufen', 'Meter', 'Platz', 'loko', 'Bank', 'Aktie', 'Pferd', 'Ferner', 'Dividende', 'Bremen', 'rennen']
# TOPIC 6
# ['verk', 'kaufen', 'Piano', 'verkaufen', 'Verk', 'billig', 'Bill', 'Tisch', 'Sofa', 'Kauf', 'preiswert', 'verkauf', 'Teppich', 'Bett', 'Stuehle']
# TOPIC 7
# ['Mutter', 'schreiben', 'sterben', 'Kind', 'Hilfe', 'Vater', 'Pastor', 'Abend', 'Lehrer', 'Theater', 'jung', 'lassen', 'reich', 'Familie', 'Sohn']
# TOPIC 8
# ['unae', 'ISIS', 'unil', 'Sonnt', 'uncl', 'Unck', 'aeer', 'Hamb', 'Limmer', 'breit', 'aesr', 'Stoff', 'luer', 'direkt', 'Vorm']
# TOPIC 9
# ['suchen', 'Gesucht', 'tuechtig', 'Lehrling', 'sofort', 'dauernd', 'gesucht', 'Meld', 'Ostern', 'Tuecht', 'Suche', 'Altona', 'Laufbursche', 'Lohn', 'Tischler']
# TOPIC 10
# ['Rang', 'Akte', 'Parkett', 'Anfang', 'Ansang', 'Gastspiel', 'Szene', 'Lustspiel', 'Musik', 'Abonnement', 'Balkon', 'Reihe', 'Operette', 'Dirigent', 'Direktion']
# TOPIC 11
# ['Juni', 'November', 'Brief', 'Name', 'Feld', 'nich', 'Zweck', 'liegen', 'groeßt', 'bringen', 'Verlag', 'Lied', 'Leipzig', 'Leben', 'Ausstellung']
# TOPIC 12
# ['Regierung', 'englisch', 'Krieg', 'deutsch', 'russisch', 'Drahtmeldung', 'London', 'Truppe', 'Deutschland', 'Feind', 'franzoesisch', 'England', 'feindlich', 'Front', 'deutsche']
# TOPIC 13
# ['gestern', 'Dampfer', 'angeklagter', 'müssen', 'Arbeiter', 'treffen', 'Versammlung', 'Schiff', 'bringen', 'schaffen', 'waehrend', 'Feuer', 'beschließen', 'Fall', 'Verein']

# %%
timespan_1.assign_topics(["real estate", "products", "random", "weddings","school", "race", "sales", "family", "random", "hiring", "theatre", "culture", "war", "boats"])
l.PL.plot_num_of_articles_per_topic(timespan_1)
timespan_1.save()
# Out:
# Keyword telefon most likely belongs to topics :
#   - SCHOOL : topic(s) 4
#   - SALES : topic(s) 6
#   - THEATRE : topic(s) 10
#   - BOATS : topic(s) 13

# %% [markdown]
# ### Second time period : 1920-1935

# %%
timespan_2 = l.PR.Timespan(df, "telephone", "ger", 1)
# Out:
# Timespan from 1920 to 1934 has 1197 articles.
# Successfully loaded model.
# TOPIC 0
# ['Juli', 'Bremen', 'Heimr', 'Pass', 'Dtsch', 'Juni', 'Rotterdam', 'AuSr', 'Maer', 'April', 'August', 'Maerz', 'Masch', 'Junt', 'Leder']
# TOPIC 1
# ['deutsch', 'ueber', 'Dampfer', 'stehen', 'letzter', 'bringen', 'lassen', 'fuer', 'gestern', 'sehen', 'sprechen', 'Deutschland', 'geben', 'halten', 'Mensch']
# TOPIC 2
# ['suchen', 'leer', 'Miete', 'Moebl', 'verk', 'Bill', 'verm', 'billig', 'Sonn', 'Zimmer', 'Suche', 'Verk', 'Laden', 'Hamb', 'Altona']
# TOPIC 3
# ['nich', 'Prokura', 'Heirat', 'erloschen', 'erteilen', 'Firma', 'Inhaber', 'Heir', 'grau', 'Heinrich', 'hett', 'Froo', 'Sick', 'mien', 'bestellen']
# TOPIC 4
# ['Pension', 'Wald', 'Pens', 'Post', 'Prospekt', 'preise', 'Verpfleg', 'Wasser', 'direkt', 'Verpflegung', 'Nebenkosten', 'Zart', 'Preis', 'Pensionspreis', 'Walde']

# %%
timespan_2.assign_topics(["cities", "boats", "sales", "companies", "real estate"])
l.PL.plot_num_of_articles_per_topic(timespan_2)
timespan_2.save()
# Out:
# Keyword telefon most likely belongs to topics :
#   - REAL ESTATE : topic(s) 4
#   - COMPANIES : topic(s) 3
#   - SALES : topic(s) 2
#   - CITIES : topic(s) 0

# %% [markdown]
# ### Third time period : 1935 onwards

# %%
timespan_3 = l.PR.Timespan(df, "telephone", "ger", 2)
# Out:
# Timespan from 1935 to 1945 has 3129 articles.
# Successfully loaded model.
# TOPIC 0
# ['Heirat', 'Frau', 'Heir', 'Herr', 'Witwe', 'Angeb', 'zwecks', 'wuenschen', 'nett', 'Maedel', 'Bild', 'spaet', 'moechen', 'fest', 'Zuschr']
# TOPIC 1
# ['Zimmer', 'leer', 'verm', 'Sonn', 'vermieten', 'Miete', 'Moebl', 'Naeb', 'Balk', 'Wohnung', 'Naeh', 'vermiet', 'Wohn', 'monatlich', 'Garten']
# TOPIC 2
# ['deutsch', 'stehen', 'sehen', 'schwer', 'bringen', 'letzter', 'lassen', 'ueber', 'Mensch', 'Leben', 'bleiben', 'liegen', 'spielen', 'waehrend', 'Deutschland']
# TOPIC 3
# ['Heimr', 'verk', 'verkaufen', 'Hansestadt', 'kaufen', 'billig', 'verlausen', 'AuSr', 'Verl', 'Tisch', 'Gebr', 'Bill', 'Verk', 'Juni', 'Schlafzimmer']
# TOPIC 4
# ['suchen', 'sofort', 'aesucht', 'Maedche', 'leicht', 'fuer', 'Gesucht', 'tuechtig', 'Antritt', 'Dauerstellung', 'jung', 'Haushalt', 'Baeckerei', 'Stellung', 'Fuer']

# %%
timespan_3.assign_topics(["weddings", "real estate", "germany", "sales", "hiring"])
l.PL.plot_num_of_articles_per_topic(timespan_3)
timespan_3.save()
# Out:
# Keyword telefon most likely belongs to topics :
#   - HIRING : topic(s) 4
#   - SALES : topic(s) 3
#   - REAL ESTATE : topic(s) 1
#   - WEDDINGS : topic(s) 0

# %% [markdown]
# ## Overall top 10 topics

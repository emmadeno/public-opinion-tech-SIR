# %% [markdown]
# # USA topic analysis - Telephone

# %% [markdown]
# #### 0. Dependencies and Setup

# %%
import sys
sys.path.insert(0, '../..')
import lib as l

# %%
df = l.U.load_df("USA", keyword="telephone", is_parent=False)
# Out:
# Loaded data from USA, took 7.85 seconds
# Dataset has size (18265, 3) and columns ['date' 'article' 'lemmas']

# %%
l.PL.plot_articles_over_time(df, "telephone")

# %%
l.PL.plot_occurences(df, "telephone", l.C.TELEPHONE["eng"])

# %% [markdown]
# ## Analyze topic modelling

# %% [markdown]
# ### First time period : 1840-1870

# %%
timespan_1 = l.PR.Timespan(df, "telephone", "eng", 0)
# Out:
# Timespan from 1840 to 1869 has 355 articles.
# Successfully loaded model.
# TOPIC 0
# ['price', 'assortment', 'Broadway', 'article', 'instrument', 'retail', 'street', 'wholesale', 'hair', 'Fulton', 'offer', 'cent', 'stock', 'Wall', 'style']
# TOPIC 1
# ['John', 'Mary', 'Smith', 'Henry', 'James', 'Capt', 'Brown', 'Edward', 'Patrick', 'Thomas', 'Sarah', 'Martin', 'William', 'David', 'George']
# TOPIC 2
# ['word', 'Bible', 'character', 'language', 'school', 'society', 'Lord', 'race', 'dress', 'idea', 'sound', 'white', 'represent', 'history', 'Austria']
# TOPIC 3
# ['night', 'evening', 'appear', 'theatre', 'hear', 'prisoner', 'play', 'yesterday', 'woman', 'move', 'house', 'opera', 'perform', 'morrow', 'crowd']
# TOPIC 4
# ['General', 'army', 'rebel', 'regiment', 'government', 'officer', 'enemy', 'troop', 'Colonel', 'battle', 'right', 'drive', 'command', 'british', 'horse']
# TOPIC 5
# ...

# %%
timespan_1.assign_topics(["sales", "random", "religion", "theatre", "war","travel", "funeral", "politics", "hiring", "random", "boats","random", "medicine"])
l.PL.plot_num_of_articles_per_topic(timespan_1)
timespan_1.save()
# Out:
# Keyword telephone not in vocabulary used to train model.

# %% [markdown]
# ### Second time period : 1870-1880

# %%
timespan_2 = l.PR.Timespan(df, "telephone", "eng", 1)
# Out:
# Timespan from 1870 to 1879 has 1247 articles.
# Successfully loaded model.
# TOPIC 0
# ['year', 'street', 'tlio', 'prize', 'morning', 'place', 'invite', 'Church', 'funeral', 'State', 'late', 'book', 'John', 'receive', 'number']
# TOPIC 1
# ['yesterday', 'people', 'come', 'government', 'know', 'Judge', 'think', 'report', 'length', 'pass', 'fact', 'race', 'England', 'question', 'matter']
# TOPIC 2
# ['bark', 'steady', 'dull', 'Schr', 'head', 'bushel', 'brig', 'weight', 'April', 'York', 'middling', 'Liverpool', 'Baltimore', 'quiet', 'wheat']
# TOPIC 3
# ['MATINEE', 'street', 'Miss', 'SATURDAY', 'THEATRE', 'theatre', 'evening', 'avenue', 'EVENING', 'MONDAY', 'concert', 'opera', 'admission', 'grand', 'WEEK']
# TOPIC 4
# ['Herald', 'Harness', 'office', 'reference', 'Broadway', 'warrant', 'draw', 'Address', 'Wagon', 'private', 'trot', 'horse', 'Uptown', 'room', 'near']
# TOPIC 5
# ...

# %%
timespan_2.assign_topics(["funeral", "politics", "boats", "theatre", "public interest", "boats"])
l.PL.plot_num_of_articles_per_topic(timespan_2)
timespan_2.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - FUNERAL : topic(s) 0
#   - BOATS : topic(s) 2, 5
#   - THEATRE : topic(s) 3
#   - POLITICS : topic(s) 1
#   - PUBLIC INTEREST : topic(s) 4

# %% [markdown]
# ### Third time period : 1920-1922

# %%
timespan_3 = l.PR.Timespan(df, "telephone", "eng", 2)
# Out:
# Timespan from 1920 to 1922 has 16658 articles.
# Successfully loaded model.
# TOPIC 0
# ['premise', 'Hotel', 'HOTEL', 'Bath', 'Elllman', 'amusement', 'hotel', 'Mats', 'RESORTS', 'Booklet', 'dancing', 'Sharp', 'Golf', 'Ocean', 'RIVERSIDE']
# TOPIC 1
# ['touring', 'sedan', 'passenger', 'condition', 'model', 'limousine', 'perfect', 'body', 'bargain', 'tire', 'tour', 'overhaul', 'PACKARD', 'MOTOR', 'coupe']
# TOPIC 2
# ['experience', 'salary', 'opportunity', 'SALESMEN', 'Herald', 'salesman', 'want', 'apply', 'commission', 'require', 'work', 'help', 'SALESMAN', 'permanent', 'advancement']
# TOPIC 3
# ['game', 'team', 'defeat', 'score', 'Capt', 'race', 'play', 'second', 'champion', 'Club', 'round', 'championship', 'match', 'bait', 'Yale']
# TOPIC 4
# ['room', 'bath', 'apartment', 'rent', 'house', 'garage', 'elevator', 'furnish', 'floor', 'electricity', 'plot', 'modern', 'heat', 'kitchenette', 'acre']
# TOPIC 5
# ...

# %%
timespan_3.assign_topics(["hotel", "car","hiring",  "competition", "real estate", "stock", "boats", "hiring", "real estate", "textile", "random", "crime", "funeral", "politics"])
l.PL.plot_num_of_articles_per_topic(timespan_3)
timespan_3.save()
# Out:
# Keyword telephone most likely belongs to topics :
#   - HIRING : topic(s) 2, 7
#   - REAL ESTATE : topic(s) 4, 8
#   - CRIME : topic(s) 11
#   - CAR : topic(s) 1
#   - BOATS : topic(s) 6
#   - POLITICS : topic(s) 13
#   - TEXTILE : topic(s) 9
#   - FUNERAL : topic(s) 12
#   - HOTEL : topic(s) 0
#   - STOCK : topic(s) 5

# %% [markdown]
# ## Overall top 10 topics
